# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("hunman/train.csv")

# %%
data
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
data['Activity'].value_counts()

# %%
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
df = data.copy()

# %%
df['Activity'] = df['Activity'].map({ 'STANDING' : 1 , 'LAYING' : 0, 'SITTING':2,'WALKING':3,'WALKING_UPSTAIRS':4,'WALKING_DOWNSTAIRS':5})

# %%
df = df.dropna()

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# plt.figure(figsize=[10,14])
# sns.heatmap(a,annot=True)
# plt.show()
# 추후에 돌려보기

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split

# %%
df['Activity'].value_counts()
# Out:
# 0    1407
# 1    1374
# 2    1286
# 3    1226
# 4    1073
# 5     986
# Name: Activity, dtype: int64

# %%
df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
X = df.iloc[:,:-1]

# %%
X.drop('Ac
# Out:
#   Input In [23]
#     X.drop('Ac
#               ^
# SyntaxError: EOL while scanning string literal

# %%
temp = df.columns

# %%
for a in temp:
    if df[a].isna().sum()!=0:
        print(a)

# %%
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,shuffle=True,random_state=1012, stratify=y)

# %%
sc = StandardScaler()
X_std_train = sc.fit_transform(X_train)

# %%
y_std_train = y_train.values

# %%
from sklearn.model_selection import GridSearchCV

# %%
svc = SVC()
RF = RandomForestClassifier()
DC = DecisionTreeClassifier()

# %%
svc_param ={
    'C' : range(1,20,2),
    'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'degree' : range(3,50,4),
}

# %%
RF_param ={
    'n_estimators': range(50,300,50),
    'max_depth' : range(5,50,4),
    'min_samples_split' : range(5,30,4),
}

# %%
DC_param ={
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_depth' : range(5,50,5),
    'min_samples_split' : range(5,55,10)
}

# %%
svc_grid = GridSearchCV(svc, svc_param)

# %%
DC_grid = GridSearchCV(DC, DC_param)
RF_grid = GridSearchCV(RF, RF_param)

# %%
X_std_train.shape
# Out:
# (5881, 562)

# %%
svc_grid.fit(X_std_train,y_std_train)

# %%
RF_grid.fit(X_std_train,y_std_train)

# %%
DC_grid.fit(X_std_train,y_std_train)

# %%
knn = KNeighborsClassifier()

# %%
knn_param={}

# %%
knn.fit(X_std_train,y_std_train)
