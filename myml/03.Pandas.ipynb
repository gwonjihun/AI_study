# %% [markdown]
# # Pandas

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data ={
    'name' : ['John', 'Tom', 'Alice'],
    'point' : [3,5,4],
    'Pass' : [False,True,False]
}

df =pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

# %%
data
# Out:
# {'name': ['John', 'Tom', 'Alice'],
#  'point': [3, 5, 4],
#  'Pass': [False, True, False]}

# %%
df
# Out:
#     name  point   Pass
# 0   John      3  False
# 1    Tom      5   True
# 2  Alice      4  False

# %%
df_dummis = pd.get_dummies(df['name'],prefix="name")

# %%
titanic = pd.read_csv("datasets/titanic.csv", encoding ="UTF-8")

# %%
titanic.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
pd.get_dummies(titanic.Embarked)
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
type(titanic[["Embarked","Pclass"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic["Pclass"])
# Out:
# pandas.core.series.Series

# %%
type(titanic[["Pclass"]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.loc[titanic["Embarked"]=='C',:]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[:][:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
import numpy as np

# %% [raw]
# titanic.sort_index(axis=0, ascending= False)

# %%
titanic[:10].select_dtypes(include='number')
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
# 5            6         0       3   NaN      0      0   8.4583
# 6            7         0       1  54.0      0      0  51.8625
# 7            8         0       3   2.0      3      1  21.0750
# 8            9         1       3  27.0      0      2  11.1333
# 9           10         1       2  14.0      1      0  30.0708

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
def f1(x):
    if x == "male":
        return 1
    else:
        return 0

# %%
titanic.Sex = titanic.Sex.apply(f1)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.Survived.apply(lambda x:
# Out:
#   Input In [26]
#     titanic['Survived'].apply(lambda x: "safa" if x=1 else "die")
#                                                    ^
# SyntaxError: invalid syntax

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x= titanic.fillna(0)
x.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   0.0      0      0
# ...

# %%
titanic.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
644+168+77
# Out:
# 889

# %% [markdown]
# 범주형 NAN의 경우 count가 높은 곳을 위주로 넣어준다.

# %%
titanic.Embarked = titanic.Embarked.fillna("S")

# %%
titanic.drop(label = ["Cabin"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 titanic.drop(label = ["Cabin"],axis=1)
#
# File ~\anaconda3\envs\myml\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: drop() got an unexpected keyword argument 'label'

# %%
titanic.drop(columns=["Cabin"],axis=1,inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
sr = titanic["Embarked"].value_counts()

# %%
import matplotlib.pyplot as plt

plt.bar(sr.index, sr.values)
plt.xticks(rotation=45)
plt.show()

# %%
male = titanic[titanic["Sex"]==1].Age.mean()
female = titanic[titanic["Sex"]==0].Age.mean()

# %%
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\027\AppData\Local\Temp\ipykernel_2772\1540821821.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print('''male : {} , female : {} '''(male,female))
# C:\Users\027\AppData\Local\Temp\ipykernel_2772\1540821821.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print('''male : {} , female : {} '''(male,female))
# C:\Users\027\AppData\Local\Temp\ipykernel_2772\1540821821.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print('''male : {} , female : {} '''(male,female))
# C:\Users\027\AppData\Local\Temp\ipykernel_2772\1540821821.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   print('''male : {} , female : {} '''(male,female))
# ...
